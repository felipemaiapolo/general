# %%
import PIL
from PIL import Image
import numpy as np
from matplotlib import cm
import seaborn as sns
import matplotlib.pyplot as plt

# %%
image = Image.open("clube.jpg")
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=768x768 at 0x7FDC482C6588>

# %%
greyscale_img = image.convert('LA')
greyscale_img
# Out:
# <PIL.Image.Image image mode=LA size=768x768 at 0x7FDC482C64A8>

# %%
M=np.array(greyscale_img)
M.shape
# Out:
# (768, 768, 2)

# %%
U, S, V = np.linalg.svd(M[:,:,0])
U.shape,s.shape,V.shape
# Out:
# ((768, 768), (768,), (768, 768))

# %%
img=[]
for i in range(75):
    lamb=np.diag(S)
    lamb[i:,i:]=0
    M_re=U@lamb@V
    #M_re=np.real(M_re)
    M_re=M_re
    M_re.shape
    img.append(Image.fromarray(np.uint8(M_re) , 'L'))

# %%
im.save('clube.gif', save_all=True, append_images=img, duration=175, loop=0)
